# %%
import requests
t=requests.get('https://www.carterislandtw.com/categories/bugcat-capoo')
print(t.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-hant">
# <head>
#
#
#       <title>貓貓蟲-咖波</title>
#
#
#       <meta name="description" content="貓貓蟲-咖波">
#
#
#
#   <link rel="preload" href="https://cdn.jsdelivr.net/labjs/2.0.3/LAB.min.js" as="script">
# <link rel="preload" href="https://cdn.shopify.com/s/javascripts/currencies.js" as="script">
# <link rel="preload" href="https://cdn.shoplineapp.com/assets/common-dbbe6f36fc6edfd19d0c5f560c317188.js" as="script">
# <link rel="preload" href="https://cdn.shoplineapp.com/assets/shop-f3717386baf1ef3f5178824d171aee9f.js" as="script">
# <link rel="preload" href="https://cdn.shoplineapp.com/fonts/fontawesome-webfont.woff2?v=4.7.0" as="font" type="font/woff2" crossorigin>
# <meta name="viewport" content="initial-scale=1.0, viewport-fit=cover">
# <meta name="apple-mobile-web-app-capable" content="yes" />
#
# <meta name="google" value="notranslate">
#
#
# ...
